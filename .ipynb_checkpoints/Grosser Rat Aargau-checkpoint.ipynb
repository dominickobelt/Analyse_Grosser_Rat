# %% [markdown]
# Das Programm soll eine Liste mit allen Motionen, Interpellationen und Postulaten erstellen, die im aktuellen Jahr (oder später in einer einstellbaren Zeitperiode) im Grossen Rat Aargau eingereicht wurden.
# Es soll ausgewertet werden, welche Parlamentarier wieviele Vorstösse eingereicht haben und welche Parlamentarier und Parteien besonders oft zusammengearbeitet haben

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from bs4 import BeautifulSoup
import time
import os
import re
import pandas as pd
from tqdm import tqdm
import urllib.parse
from pathlib import Path

# %%
#mit firstyeahr und lastyeahr soll später die Zeitspanne angegeben werden, in der die Geschäfte ausgewertete werden
firstyear = 2021
lastyear = 2021

#FUNKTIONEN UND LISTE MIT BEZIRKEN-GEMEINDEN

#Funktion, um alle weiteren Seiten abzuspeichern
def save_site(page,count):
    driver.find_element_by_xpath(page).click()
    time.sleep(2)
    page = driver.page_source.encode('utf-8')
    file = open("pages/parl/parl"+str(count)+".htm", "wb+")
    file.write(page)
    file.close()
    count += 1
    return count


#Funktion, um alle weiteren Seiten abzuspeichern
def save_site_vorstoesse(page_vorstoesse,count_vorstoesse):
    driver.find_element_by_xpath(page_vorstoesse).click()
    time.sleep(2)
    page = driver.page_source.encode('utf-8')
    file = open("pages/vorstoesse/"+adrid+"/"+str(count_vorstoesse)+".htm", "wb+")
    file.write(page)
    file.close()
    count_vorstoesse += 1
    return count_vorstoesse

#Hier bilde ich aus der Geschäftsnummer-ID das Jahr des Geschäfts
def trennen(elem):
    datum = elem.split(".")[0]
    datum = datum.replace('="', "")
    datum = datum_umwandeln(datum)
    return datum

#Mit dieser Funktion wird die zweistellige Zahl aus der Geschäfts-ID in eine 4-stellige Jahreszahl umgewandelt
def datum_umwandeln(jahr):
    jahr_neu = pd.to_datetime(jahr, format='%y')
    jahr_neu = jahr_neu.strftime("%Y")
    return jahr_neu

#Mit der Funktion prüfen wir, ob eine (oder mehrere) Partei(en) an einem Vorstoss beteiligt sind
def check_partei(id_vorstoss,parteien):
    a = list_vorstoesse_namen[list_vorstoesse_namen["ID Vorstoss"] == id_vorstoss]["Partei"]
    #Nur eine Partei
    if len(parteien) == 1:
        if parteien[0] in a.unique():
            result=1
        else:
            result=0
    #2 Parteien
    if len(parteien) == 2:
        if parteien[0] in a.unique() and parteien[1] in a.unique():
            result=1
        else:
            result=0
    #3 Parteien
    if len(parteien) == 3:
        if parteien[0] in a.unique() and parteien[1] in a.unique() and parteien[2] in a.unique():
            result=1
        else:
            result=0
    return(result)

#(AG) aus den Ortsnahmen entfernen
def ag_entf(gemeinde):
    gemeinde = gemeinde.replace(' (AG)', "")
    return gemeinde

#Dict mit allen Bezirken, mit Listen aller Gemeinden
bezirke = {"Aarau":[],"Baden":[],"Bremgarten":[],"Brugg":[],"Kulm":[],"Laufenburg":[],"Lenzburg":[],"Muri":[],"Rheinfelden":[],"Zofingen":[],"Zurzach":[]}
for bezirk in bezirke:
    if bezirk == "Baden":
        adresse = "https://de.wikipedia.org/wiki/Bezirk_"+bezirk+"_(Aargau)"
    else:
        adresse = "https://de.wikipedia.org/wiki/Bezirk_"+bezirk
    res=pd.read_html(adresse)
    bezirke[bezirk] = res[2]["Name der Gemeinde"].apply(ag_entf)
    bezirke[bezirk].pop(len(bezirke[bezirk])-1)

#Funktion, um Bezirk zuzuordnen
def def_bezirk(gemeinde):
    for bezirk in bezirke:
        if gemeinde in bezirke[bezirk].unique():
            return "Bezirk "+bezirk
        
#Funktion, um Vorstösse zu zählen
def anzahl_vorstoesse(name):
    anzahl = list_vorstoesse_namen[list_vorstoesse_namen["Name"]==name].count()[0]
    return anzahl

# %%
#Zuerst werden alle Parlamentarier erfasst. 
#Dazu werden die entsprechenden Websiten heruntergeladen und jeder Parlamentarier als Dict  mit Partei/Ort/Link/ID erstellt 

#Neues Fenster mit 1. Seite aufrufen
driver = webdriver.Firefox()
driver.get('https://www.ag.ch/grossrat/grweb/de/164/Ratsmitglieder?')
#Variable count definieren, für Funktion save_site
count = 2

    
#Seite 1 abspeichern
page = driver.page_source.encode('utf-8')
file = open("pages/parl/parl1.htm", "wb+")
file.write(page)
file.close()


#Seiten 2-6
sites = ["/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[1]",
        "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[4]",
        "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]",
        "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]",
        "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[6]"]

#Für alle Seiten Funktion save_site aufrufen, und count hochzählen
for site in sites:
    #print(site)
    count = save_site(site,count)

#falls Probleme auftauchen, driver.quit ist noch nicht getestet!!
driver.quit()

# %%
#Im Ordner auslesen, welche Seiten gespeichert wurden
lst = os.listdir('pages/parl/')

#Leere Liste erstellen. Hier kommen die Inhalte der Seiten rein
list_of_pages=[]

#Alle gespeicherten Seiten in die Liste list_of_pages schreiben
for i in range(0,len(lst)):
    file = open('pages/parl/' + lst[i], 'r', encoding='utf-8')
    text = file.read()
    list_of_pages.append(BeautifulSoup(text, 'html.parser'))

# %%
#Leere Liste erstellen. Hier kommen alle Politiker als Minidict rein (Name,Partei, Ort, Link)
politicians = []

#Für jede Seite, die in list_of_pages abgespeichert ist
for page in list_of_pages:
    result = page.find_all('table', {'class', 'table'})[0]

    #Suche in der jeder Zeile der Tabelle nach den entsprechenden Einträgen, speichere als Minidict in die Liste
    for politician in result.find_all('tr')[1:]:
        par = politician.find_all('td')[0].text
        link = politician.find_all('a')[0].get('href')
        #Ich suche nach 'AdrId=', gefolgt von Zahlen. Durch die Klammern wird der String aufgeteilt, mit group(1) gebe ich nur die Zahlen zurück
        id_pol = re.search(r"AdrId=(\d+)", link).group(1)
        name = politician.find_all('td')[1].text
        place = politician.find_all('td')[4].text
        #print(link)
        mini_dict = {"Name":name, "Partei":par, "Ort":place, "Link":link, "ID Politiker":id_pol}
        politicians.append(mini_dict)
        try:
            os.makedirs("pages/"+id_pol)
        except FileExistsError:
            # directory already exists
            pass

# %%
pd.set_option('display.max_colwidth', 100)
list_politicians = pd.DataFrame(politicians)
list_politicians['Ort'] = list_politicians['Ort'].apply(ag_entf)
list_politicians['Bezirk'] = list_politicians['Ort'].apply(def_bezirk)
list_politicians.to_csv('aktive_parlamentarier.csv', index=False)
list_politicians
# Out:
#                   Name     Partei          Ort  \
# 0    Aebi Daniel Erich        SVP  Birmenstorf
# 1           Bally Maya  Die Mitte  Hendschiken
# 2       Basler Colette         SP       Zeihen
# 3       Baumann Thomas      Grüne         Suhr
# 4            Baur Jürg  Die Mitte        Brugg
# ..                 ...        ...          ...
# 135        Walser Rolf         SP      Aarburg
# 136      Wehrli Daniel        SVP     Küttigen
# 137      Wernli Martin        SVP     Thalheim
# 138     Wetzel Michael  Die Mitte   Ennetbaden
# 139     Winzenried Urs        SVP        Aarau
#
#                                                                        Link  \
# 0     https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=117121
# 1     https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=102445
# 2     https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=109111
# 3    https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4887870
# 4     https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=109110
# ..                                                                      ...
# 135  https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4517811
# 136    https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=87823
# 137    https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=99561
# 138   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=107573
# 139  https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4887900
#
#     ID Politiker             Bezirk
# 0         117121       Bezirk Baden
# 1         102445    Bezirk Lenzburg
# 2         109111  Bezirk Laufenburg
# 3        4887870       Bezirk Aarau
# 4         109110       Bezirk Brugg
# ..           ...                ...
# 135      4517811    Bezirk Zofingen
# 136        87823       Bezirk Aarau
# 137        99561       Bezirk Brugg
# 138       107573       Bezirk Baden
# 139      4887900       Bezirk Aarau
#
# [140 rows x 6 columns]

# %%
anzahl_gr = 0
while anzahl_gr < len(politicians):  
    adrid = list_politicians["ID"][anzahl_gr]
    
    #Neues Fenster mit 1. Seite aufrufen
    driver = webdriver.Firefox()
    driver.get('https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId='+adrid)
    #Variable count definieren, für Funktion save_site
    count = 2
    #2 Sekunden warten
    time.sleep(2)

    #Seite 1 abspeichern
    page = driver.page_source.encode('utf-8')
    if os.path.exists("pages/vorstoesse/"+adrid):
               file = open("pages/vorstoesse/"+adrid+"/1.htm", "wb+")
               file.write(page)
               file.close()
    else:
        os.makedirs("pages/vorstoesse/"+adrid)
        file = open("pages/vorstoesse/"+adrid+"/1.htm", "wb+")
        file.write(page)
        file.close()

    #file wieder öffnen, "Vorstösse" suchen und Zahl in Klammer speichern
    file = open("pages/vorstoesse/"+adrid+"/1.htm","r",encoding="UTF-8")
    text = file.read()
    h = BeautifulSoup(text, 'html.parser')
    text = h.find_all('caption')[1]
    anzahl = re.findall(r"\(([A-Za-z0-9_]+)\)", str(text)) 
    anzahl = int(anzahl[0])
    file.close()

    sites_vorstoesse = []

    if (anzahl > 25) and (anzahl <=50):
        sites_vorstoesse = ["/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[1]"]

    if (anzahl > 50) and (anzahl <=75):
        sites_vorstoesse = ["/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[1]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[4]"]

    if anzahl > 75 and anzahl <=100:
        sites_vorstoesse = ["/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[1]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[4]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]",]

    if anzahl > 100 and anzahl <=125:
        sites_vorstoesse = ["/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[1]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[4]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]"]

    if anzahl > 125 and anzahl <=150:
        sites_vorstoesse = ["/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[1]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[4]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[5]",
                "/html/body/div/div/div/div/div/article/nav[1]/p[2]/a[6]"]

    if anzahl > 150:
        print("ACHTUNG!!! Anzahl grösser 150")

    #Für alle Seiten Funktion save_site aufrufen, und count hochzählen
    count_vorstoesse = 2
    for site_vorstoesse in sites_vorstoesse:
        count_vorstoesse = save_site_vorstoesse(site_vorstoesse,count_vorstoesse)
        
    anzahl_gr+=1
print("Ich bin fertig")
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\kobelt\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\envs\kobelt\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\envs\kobelt\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ID'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7544/2646087412.py in <module>
#       1 anzahl_gr = 0
#       2 while anzahl_gr < len(politicians):
# ----> 3     adrid = list_politicians["ID"][anzahl_gr]
#       4
#       5     #Neues Fenster mit 1. Seite aufrufen
#
# ~\anaconda3\envs\kobelt\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\envs\kobelt\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'ID'

# %%
anzahl_gr = 0
#Leere Liste erstellen. Hier kommen alle Vorstösse als Minidict rein
vorstoesse = []
while anzahl_gr < len(politicians):  
    adrid = list_politicians["ID Politiker"][anzahl_gr]    
    #Im Ordner auslesen, welche Seiten gespeichert wurden
    lst = os.listdir('pages/vorstoesse/'+adrid)
    #print(lst)

    #Leere Liste erstellen. Hier kommen die Inhalte der Seiten rein
    list_of_pages_vorstoesse=[]

    #Alle gespeicherten Seiten in die Liste list_of_pages schreiben
    for i in range(0,len(lst)):
        file = open('pages/vorstoesse/'+adrid+"/" + lst[i], 'r', encoding='utf-8')
        text = file.read()
        list_of_pages_vorstoesse.append(BeautifulSoup(text, 'html.parser'))



    #Für jede Seite, die in list_of_pages abgespeichert ist
    for page in list_of_pages_vorstoesse:
        result = page.find_all('table', {'class', 'table'})[2]

        #Suche in der jeder Zeile der Tabelle nach den entsprechenden Einträgen, speichere als Minidict in die Liste
        for vorstoss in result.find_all('tr')[1:]:
            id_vorstoss = vorstoss.find_all('td')[0].text
            #vorstoesse.append(id_vorstoss)
            text_vorstoss = vorstoss.find_all('td')[1].text
            art_vorstoss = vorstoss.find_all('td')[2].text
            mini_dict = {"ID Vorstoss":id_vorstoss, "ID Politiker":adrid, "Art":art_vorstoss, "Text":text_vorstoss}
            vorstoesse.append(mini_dict)
            
    anzahl_gr+=1
print("Ich bin feeeidsch")

list_vorstoesse = pd.DataFrame(vorstoesse)
# Out:
# Ich bin feeeidsch

# %%
#Zuerst die Jahreszahl rauslsen und in eine neue Spalte schreiben
list_vorstoesse['Jahr'] = list_vorstoesse['ID Vorstoss'].apply(trennen).astype(int)

#Nur den Teil aus der Zeitspanne rausfiltern, der oben angegeben ist
list_vorstoesse = list_vorstoesse[(list_vorstoesse['Jahr'] >= firstyear) & (list_vorstoesse['Jahr'] <= lastyear)]

# %%
#Die Liste der Vorstösse mit der Liste der Politiker kombinieren, Link rauslöschen
list_vorstoesse_namen = list_vorstoesse.merge(list_politicians, how='inner', on='ID Politiker')
list_vorstoesse_namen  = list_vorstoesse_namen.drop(["Link"], axis=1)

# %%
### AUSWERTUNG

#Hier kann man mehrere Parteien angeben, es wird die Anzahl gemeinsamer Vorstösse zurückgegeben
anzahl_gemeinsam = 0
parteien=["Die Mitte","SVP"]
for ID_Vorstoss in list_vorstoesse_namen["ID Vorstoss"].unique():
    anzahl_gemeinsam+=check_partei(ID_Vorstoss,parteien)
    
anzahl_gemeinsam
# Out:
# 19

# %%
#In die Liste der Politiker die Anzahl Vorstösse reinschreiben
list_politicians['Anzahl Vorstösse'] = list_politicians['Name'].apply(anzahl_vorstoesse)

# %%
for bezirk in bezirke:
    file = list_politicians[list_politicians["Bezirk"]=="Bezirk "+bezirk].sort_values(by=['Anzahl Vorstösse'], ascending=False)
    file.to_csv('bezirke/'+bezirk+'.csv', index=False)

# %%
list_politicians.groupby(by=["Partei"], dropna=False).sum()
# Out:
#            Anzahl Vorstösse
# Partei
# Die Mitte                69
# EVP                      24
# FDP                      49
# GLP                      36
# Grüne                    26
# SP                       68
# SVP                      64

# %%
anz_vorst = list_politicians.groupby(by=["Name"], dropna=False).sum()
anz_vorst.sort_values(by=['Anzahl Vorstösse']).tail(50)
# Out:
#                               Anzahl Vorstösse
# Name
# Hunziker Lelia                               3
# Demarmels Carol                              3
# Peter Dominik                                3
# Hottiger Tobias                              3
# Bossert Martin                               3
# Müller Werner                                3
# Dell'Anno-Doppler Regula                     3
# Häseli Gertrud                               3
# Schmidmeister Lea                            3
# Meier Maya                                   3
# Capanni Luzia                                3
# Faes Karin                                   3
# Knuchel Jürg                                 3
# Lauper Richner Gabi                          3
# Brem-Ingold Rita                             3
# Hottiger Hans-Ruedi                          3
# Bieber Béa                                   4
# Stutz Désirée                                4
# Stenico-Goldschmid Franziska                 4
# Fischer-Lamprecht Lutz                       4
# Kaufmann Tonja                               4
# Hilfiker Silvan                              4
# Glarner Jeanine                              4
# Müller-Boder Nicole                          4
# Dietiker Therese                             4
# Frauchiger Roland                            4
# Kaufmann Alfons Paul                         4
# Lütolf Harry                                 5
# Bally Maya                                   5
# Hasler Kathrin                               5
# Rotzetter Andre                              5
# Hagenbuch Christoph                          6
# Bodmer René                                  6
# Bucher Ralf                                  6
# Huwyler Stefan                               6
# Meier Titus                                  6
# Leitch-Frey Thomas                           6
# von Planta Gian                              7
# Portmann-Müller Barbara                      7
# Marclay-Merz Suzanne                         7
# Saner Edith                                  7
# Lang Markus                                  7
# Brügger Martin                               8
# Brizzi Simona                                8
# Fricker Jonas                                8
# Müri Ruth                                    8
# Baur Jürg                                    9
# Seibert Uriel                                9
# Basler Colette                              11
# Meier Andreas                               11

# %%
#Zusammenarbeit zwischen allen Parteien berechnen

alle_parteien=["SVP","FDP","SP","Die Mitte","GLP","Grüne","EVP","EDU"]
Zusammenarbeit = pd.DataFrame({'Parteien': alle_parteien})

for partei in alle_parteien:
    for partei2 in alle_parteien:
        if partei == partei2:
            pass
        else:
            anzahl_gemeinsam = 0
            parteien=[partei,partei2]
            for ID_Vorstoss in list_vorstoesse_namen["ID Vorstoss"].unique():
                anzahl_gemeinsam+=check_partei(ID_Vorstoss,parteien)
            print(partei+" und "+partei2+" "+str(anzahl_gemeinsam))
# Out:
# SVP und FDP 18
# SVP und SP 15
# SVP und Die Mitte 19
# SVP und GLP 12
# SVP und Grüne 10
# SVP und EVP 7
# SVP und EDU 0
# FDP und SVP 18
# FDP und SP 17
# FDP und Die Mitte 19
# FDP und GLP 12
# FDP und Grüne 13
# FDP und EVP 8
# FDP und EDU 0
# SP und SVP 15
# SP und FDP 17
# SP und Die Mitte 25
# SP und GLP 23
# SP und Grüne 22
# SP und EVP 18
# SP und EDU 0
# Die Mitte und SVP 19
# Die Mitte und FDP 19
# Die Mitte und SP 25
# Die Mitte und GLP 21
# Die Mitte und Grüne 20
# Die Mitte und EVP 16
# Die Mitte und EDU 0
# GLP und SVP 12
# GLP und FDP 12
# GLP und SP 23
# GLP und Die Mitte 21
# GLP und Grüne 19
# GLP und EVP 17
# GLP und EDU 0
# Grüne und SVP 10
# Grüne und FDP 13
# Grüne und SP 22
# Grüne und Die Mitte 20
# Grüne und GLP 19
# Grüne und EVP 13
# Grüne und EDU 0
# EVP und SVP 7
# EVP und FDP 8
# EVP und SP 18
# EVP und Die Mitte 16
# EVP und GLP 17
# EVP und Grüne 13
# EVP und EDU 0
# EDU und SVP 0
# EDU und FDP 0
# EDU und SP 0
# EDU und Die Mitte 0
# EDU und GLP 0
# EDU und Grüne 0
# EDU und EVP 0

# %%
list_vorstoesse_namen.groupby("Name")['ID Vorstoss'].count().sort_values()
# Out:
# Name
# Stichert Norbert       1
# Plüss Urs              1
# Gabriel Markus         1
# Hochreuter Clemens     1
# Huber René             1
#                       ..
# Müri Ruth              8
# Seibert Uriel          9
# Baur Jürg              9
# Meier Andreas         11
# Basler Colette        11
# Name: ID Vorstoss, Length: 103, dtype: int64

# %%
df.list_vorstoesse_namen()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7840/1001070983.py in <module>
# ----> 1 df.list_vorstoesse_namen()
#
# NameError: name 'df' is not defined

# %%
list_vorstoesse_namen
# Out:
#     ID Vorstoss ID Politiker               Art  \
# 0        21.272       102445          Motionen
# 1        21.243       102445         Postulate
# 2        21.141       102445  Interpellationen
# 3        21.107       102445          Motionen
# 4         21.21       102445          Motionen
# ..          ...          ...               ...
# 331      21.118      4517811  Interpellationen
# 332      21.172        87823  Interpellationen
# 333       21.18        87823  Interpellationen
# 334       21.73        99561  Interpellationen
# 335      21.174       107573          Motionen
#
#                                                                                                     Text  \
# 0    Motion Claudia Rohrer, SP, Rheinfelden, Carole Binder-Meury, SP, Magden (Sprecherin), Barbara Po...
# 1    Postulat R. Dell’Anno, SP, Baden (Sprecherin), M. Bally, Mitte, Hendschiken, B. Bieber, GLP, Rhe...
# 2    Interpellation Martin Bossert, EDU, Rothrist (Sprecher), Colette Basler, SP, Zeihen, und Maya Ba...
# 3    Motion Gertrud Häseli, Grüne, Wittnau (Sprecherin), Luzia Capanni, SP, Windisch, Béa Bieber, GLP...
# 4    Motion Maya Bally, CVP, Hendschiken (Sprecherin), Colette Basler, SP, Zeihen, Jürg Baur, CVP, Br...
# ..                                                                                                   ...
# 331  Interpellation Carol Demarmels, SP, Obersiggenthal (Sprecherin), Luzia Capanni, SP, Windisch, un...
# 332  Interpellation Daniel Wehrli, SVP, Küttigen, vom 22. Juni 2021 betreffend Prämienreduktion Feuer...
# 333      Interpellation Daniel Wehrli, SVP, Küttigen, vom 5. Januar 2021 betreffend Fusion von Gemeinden
# 334  Interpellation Christoph Riner, SVP, Zeihen (Sprecher), Erich Hunziker, SVP, Kirchleerau, Daniel...
# 335  Motion Roland Vogt, SVP, Wohlen (Sprecher), Barbara Borer-Mathys, SVP, Holziken, Rolf Jäggi, SVP...
#
#      Jahr            Name     Partei          Ort           Bezirk
# 0    2021      Bally Maya  Die Mitte  Hendschiken  Bezirk Lenzburg
# 1    2021      Bally Maya  Die Mitte  Hendschiken  Bezirk Lenzburg
# 2    2021      Bally Maya  Die Mitte  Hendschiken  Bezirk Lenzburg
# 3    2021      Bally Maya  Die Mitte  Hendschiken  Bezirk Lenzburg
# 4    2021      Bally Maya  Die Mitte  Hendschiken  Bezirk Lenzburg
# ..    ...             ...        ...          ...              ...
# 331  2021     Walser Rolf         SP      Aarburg  Bezirk Zofingen
# 332  2021   Wehrli Daniel        SVP     Küttigen     Bezirk Aarau
# 333  2021   Wehrli Daniel        SVP     Küttigen     Bezirk Aarau
# 334  2021   Wernli Martin        SVP     Thalheim     Bezirk Brugg
# 335  2021  Wetzel Michael  Die Mitte   Ennetbaden     Bezirk Baden
#
# [336 rows x 9 columns]

# %%
bezirk = def_bezirk("Brugg")
bezirk
# Out:
# 'Bezirk Brugg'

# %%
gemeinde = "Zufikon"
res=pd.read_html("https://de.wikipedia.org/wiki/Bezirk_Bremgarten")
bremgarten=res[2]["Name der Gemeinde"]
bremgarten.pop(len(df))

if "Zufikon" in bremgarten.unique():
    bezirk = "Bezrik Bremgarten"

bezirk
# Out:
# 'Bezrik Bremgarten'

# %%
brugg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10556/1047059757.py in <module>
# ----> 1 brugg
#
# NameError: name 'brugg' is not defined

# %%
bremgarten.pop(len(df))
# Out:
# 'Total (22)'

# %%
list_politicians.head(10)
# Out:
#                   Name     Partei             Ort  \
# 0    Aebi Daniel Erich        SVP     Birmenstorf
# 1           Bally Maya  Die Mitte     Hendschiken
# 2       Basler Colette         SP          Zeihen
# 3       Baumann Thomas      Grüne            Suhr
# 4            Baur Jürg  Die Mitte           Brugg
# 5       Berner Yannick        FDP           Aarau
# 6           Bieber Béa        GLP     Rheinfelden
# 7  Binder-Meury Carole         SP          Magden
# 8       Bircher Adrian        GLP           Aarau
# 9          Bodmer René        SVP  Unterlunkhofen
#
#                                                                      Link  \
# 0   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=117121
# 1   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=102445
# 2   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=109111
# 3  https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4887870
# 4   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=109110
# 5  https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4887871
# 6  https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4684063
# 7  https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=4887872
# 8   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=110298
# 9   https://www.ag.ch/grossrat/grweb/de/185/Detail%20Adresse?AdrId=102380
#
#   ID Politiker              Bezirk  Anzahl Vorstösse
# 0       117121        Bezirk Baden                 0
# 1       102445     Bezirk Lenzburg                 5
# 2       109111   Bezirk Laufenburg                11
# 3      4887870        Bezirk Aarau                 2
# 4       109110        Bezirk Brugg                 9
# 5      4887871        Bezirk Aarau                 1
# 6      4684063  Bezirk Rheinfelden                 4
# 7      4887872  Bezirk Rheinfelden                 2
# 8       110298        Bezirk Aarau                 1
# 9       102380   Bezirk Bremgarten                 6

# %%
res=pd.read_html("https://de.wikipedia.org/wiki/Bezirk_Aarau")
aarau=res[2]["Name der Gemeinde"]
aarau.pop(len(aarau)-1)
aarau
# Out:
# 0               Aarau
# 1          Biberstein
# 2          Buchs (AG)
# 3           Densbüren
# 4     Erlinsbach (AG)
# 5           Gränichen
# 6          Hirschthal
# 7            Küttigen
# 8               Muhen
# 9       Oberentfelden
# 10               Suhr
# 11     Unterentfelden
# Name: Name der Gemeinde, dtype: object

# %%
if "Biberstein" in aarau.unique():
    print("Judihui")
# Out:
# Judihui

# %%
    
bezrik = def_bezirk("Zufikon")   
bezirk
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10556/1249681334.py in <module>
# ----> 1 bezrik = def_bezirk("Zufikon")
#       2 bezirk
#
# ~\AppData\Local\Temp/ipykernel_10556/221934395.py in def_bezirk(gemeinde)
#      86 def def_bezirk(gemeinde):
#      87     for bezirk in bezirke:
# ---> 88         if gemeinde in bezirke[bezirk].unique():
#      89             return "Bezirk "+bezirk
#
# AttributeError: 'list' object has no attribute 'unique'

# %%
for bezirk in bezirke:
    bezirke["Baden"] = list(map(ag_entf, bezirke["Baden"]))
    print(bezirke[bezirk])
# Out:
# 0               Aarau
# 1          Biberstein
# 2          Buchs (AG)
# 3           Densbüren
# 4     Erlinsbach (AG)
# 5           Gränichen
# 6          Hirschthal
# 7            Küttigen
# 8               Muhen
# 9       Oberentfelden
# 10               Suhr
# 11     Unterentfelden
# Name: Name der Gemeinde, dtype: object
# ['Baden', 'Bellikon', 'Bergdietikon', 'Birmenstorf', 'Ehrendingen', 'Ennetbaden', 'Fislisbach', 'Freienwil', 'Gebenstorf', 'Killwangen', 'Künten', 'Mägenwil', 'Mellingen', 'Neuenhof', 'Niederrohrdorf', 'Oberrohrdorf', 'Obersiggenthal', 'Remetschwil', 'Spreitenbach', 'Stetten', 'Turgi', 'Untersiggenthal', 'Wettingen', 'Wohlenschwil', 'Würenlingen', 'Würenlos']
# 0                      Arni (AG)
# 1                        Berikon
# 2                Bremgarten (AG)
# 3                       Büttikon
# 4                       Dottikon
# 5                       Eggenwil
# 6             Fischbach-Göslikon
# 7                     Hägglingen
# 8                      Islisberg
# 9                          Jonen
# 10                Niederwil (AG)
# 11                 Oberlunkhofen
# 12                 Oberwil-Lieli
# 13    Rudolfstetten-Friedlisberg
# 14                   Sarmenstorf
# 15                       Tägerig
# 16                        Uezwil
# 17                Unterlunkhofen
# 18                    Villmergen
# 19                         Widen
# 20                        Wohlen
# 21                       Zufikon
# Name: Name der Gemeinde, dtype: object
# 0         Auenstein
# 1              Birr
# 2          Birrhard
# 3           Bözberg
# 4             Brugg
# 5          Habsburg
# 6       Hausen (AG)
# 7            Lupfig
# 8           Mandach
# 9           Mönthal
# 10         Mülligen
# 11          Remigen
# 12          Riniken
# 13         Rüfenach
# 14       Schinznach
# 15    Thalheim (AG)
# 16    Veltheim (AG)
# 17         Villigen
# 18      Villnachern
# 19         Windisch
# Name: Name der Gemeinde, dtype: object
# 0      Beinwil am See
# 1             Birrwil
# 2           Burg (AG)
# 3          Dürrenäsch
# 4        Gontenschwil
# 5            Holziken
# 6       Leimbach (AG)
# 7             Leutwil
# 8            Menziken
# 9            Oberkulm
# 10       Reinach (AG)
# 11        Schlossrued
# 12        Schmiedrued
# 13         Schöftland
# 14    Teufenthal (AG)
# 15          Unterkulm
# 16            Zetzwil
# Name: Name der Gemeinde, dtype: object
# 0              Böztal
# 1               Eiken
# 2               Frick
# 3           Gansingen
# 4      Gipf-Oberfrick
# 5            Herznach
# 6             Kaisten
# 7          Laufenburg
# 8         Mettauertal
# 9     Münchwilen (AG)
# 10            Oberhof
# 11           Oeschgen
# 12       Schwaderloch
# 13            Sisseln
# 14              Ueken
# 15            Wittnau
# 16        Wölflinswil
# 17             Zeihen
# Name: Name der Gemeinde, dtype: object
# 0            Ammerswil
# 1             Boniswil
# 2              Brunegg
# 3             Dintikon
# 4             Egliswil
# 5           Fahrwangen
# 6              Hallwil
# 7          Hendschiken
# 8      Holderbank (AG)
# 9         Hunzenschwil
# 10            Lenzburg
# 11    Meisterschwanden
# 12     Möriken-Wildegg
# 13          Niederlenz
# 14        Othmarsingen
# 15          Rupperswil
# 16         Schafisheim
# 17             Seengen
# 18                Seon
# 19             Staufen
# Name: Name der Gemeinde, dtype: object
# 0                Abtwil
# 1               Aristau
# 2                   Auw
# 3     Beinwil (Freiamt)
# 4            Besenbüren
# 5               Bettwil
# 6                Boswil
# 7                Bünzen
# 8               Buttwil
# 9               Dietwil
# 10              Geltwil
# 11              Kallern
# 12         Merenschwand
# 13               Mühlau
# 14            Muri (AG)
# 15             Oberrüti
# 16         Rottenschwil
# 17                 Sins
# 18         Waltenschwil
# Name: Name der Gemeinde, dtype: object
# 0         Hellikon
# 1      Kaiseraugst
# 2           Magden
# 3           Möhlin
# 4            Mumpf
# 5        Obermumpf
# 6          Olsberg
# 7      Rheinfelden
# 8        Schupfart
# 9       Stein (AG)
# 10        Wallbach
# 11    Wegenstetten
# 12       Zeiningen
# 13          Zuzgen
# Name: Name der Gemeinde, dtype: object
# 0          Aarburg
# 1        Bottenwil
# 2         Brittnau
# 3      Kirchleerau
# 4         Kölliken
# 5       Moosleerau
# 6       Murgenthal
# 7        Oftringen
# 8          Reitnau
# 9         Rothrist
# 10        Safenwil
# 11     Staffelbach
# 12    Strengelbach
# 13        Uerkheim
# 14      Vordemwald
# 15        Wiliberg
# 16        Zofingen
# Name: Name der Gemeinde, dtype: object
# 0          Böttstein
# 1          Döttingen
# 2           Endingen
# 3           Fisibach
# 4     Full-Reuenthal
# 5           Klingnau
# 6            Koblenz
# 7          Leibstadt
# 8       Lengnau (AG)
# 9           Leuggern
# 10          Mellikon
# 11      Schneisingen
# 12        Siglistorf
# 13       Tegerfelden
# 14           Zurzach
# Name: Name der Gemeinde, dtype: object

# %%
bezirke["Bremgarten"]
# Out:
# 0                           Arni
# 1                        Berikon
# 2                     Bremgarten
# 3                       Büttikon
# 4                       Dottikon
# 5                       Eggenwil
# 6             Fischbach-Göslikon
# 7                     Hägglingen
# 8                      Islisberg
# 9                          Jonen
# 10                     Niederwil
# 11                 Oberlunkhofen
# 12                 Oberwil-Lieli
# 13    Rudolfstetten-Friedlisberg
# 14                   Sarmenstorf
# 15                       Tägerig
# 16                        Uezwil
# 17                Unterlunkhofen
# 18                    Villmergen
# 19                         Widen
# 20                        Wohlen
# 21                       Zufikon
# Name: Name der Gemeinde, dtype: object

# %%
def double(integer):
    return integer*2
  
  
# driver code
integer_list = [1, 2, 3]
  
# Map method returns a map object
# so we cast it into list using list()
output_list = 
  
print(output_list)
# Out:
# ['Baden', 'Bellikon', 'Bergdietikon', 'Birmenstorf', 'Ehrendingen', 'Ennetbaden', 'Fislisbach', 'Freienwil', 'Gebenstorf', 'Killwangen', 'Künten', 'Mägenwil', 'Mellingen', 'Neuenhof', 'Niederrohrdorf', 'Oberrohrdorf', 'Obersiggenthal', 'Remetschwil', 'Spreitenbach', 'Stetten', 'Turgi', 'Untersiggenthal', 'Wettingen', 'Wohlenschwil', 'Würenlingen', 'Würenlos']
